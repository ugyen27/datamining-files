# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
import missingno as msno 
import warnings
warnings.filterwarnings('ignore')

# %%
data=sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# data.describe()
# data.tail()
# data.columns
data.head(10)
# data.tail(20)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# # To find the Missing values in dataset.

# %%
# data.isna().sum()
# data.notna()
# data.isna()
# data.isnull()
# data.notnull()
# data.isnull().sum()
# data.notnull().sum()
data.isna().sum()
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#To count the total missing values in particular column
# data['age'].isnull().sum()
# data['who'].isnull().sum()
# data['deck'].isnull().sum()
# data.isna().sum()

# %% [markdown]
# # Unique values: unique() and value_counts()

# %%
# pd.unique(data['who'])
# pd.unique(data['age'])
# pd.unique(data['sex'])
# data['sex'].value_counts()
# data['deck'].value_counts()
# data['class'].value_counts()
pd.unique(data['class'])
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %% [markdown]
# # Visualization of Missing values

# %%
#matrix plot 
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # This graph shows that the deck attribute has the maximum missing values followed by the age column.

# %%
msno.matrix(data, figsize=(20,4), fontsize=12, color=(0.3,0.9,0.1))
# Out:
# <AxesSubplot:>

# %%
#Bar chart
# msno.bar(data)
msno.bar(data,color='black',sort='ascending')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # This bar graph determines that the deck attribute has got the maximum missing values.

# %%
msno.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
#dendogram
msno.dendrogram(data, orientation="top")
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # This dendogram tells about the heiarchical relationship among the clustered columns having more nullity relation.

# %% [markdown]
# # solutions for the missing values(various methods)

# %%
#dropna
data2 = data.dropna(axis=0) # for the rows and axis=1 is for dropping column
data2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.dropna(axis=1, inplace=True) #Removes an original dataset
data
# Out:
#      survived  pclass     sex  sibsp  parch   class    who  adult_male alive  \
# 0           0       3    male      1      0   Third    man        True    no
# 1           1       1  female      1      0   First  woman       False   yes
# 2           1       3  female      0      0   Third  woman       False   yes
# 3           1       1  female      1      0   First  woman       False   yes
# 4           0       3    male      0      0   Third    man        True    no
# ..        ...     ...     ...    ...    ...     ...    ...         ...   ...
# 886         0       2    male      0      0  Second    man        True    no
# 887         1       1  female      0      0   First  woman       False   yes
# 888         0       3  female      1      2   Third  woman       False    no
# 889         1       1    male      0      0   First    man        True   yes
# 890         0       3    male      0      0   Third    man        True    no
#
#      alone
# 0    False
# 1    False
# ...

# %%
data3 = data.dropna(axis=1)
data3
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %%
data
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %% [markdown]
# # 2. Filling with a Global Constant
# # fillna()

# %%
# mydf = data['age'].fillna('unkown')
mydf = data['deck'].fillna('A') #for only values in the deck catetory can be filled with.
mydf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'deck'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
mydf.isnull().sum()

# %%
mydf.isnull()

# %% [markdown]
# # 3. Imputation using mean, median or mode

# %%
# imputeValue = data['age'].mean()
# imputeValue
data['age'].fillna(imputeValue, inplace=True)
data

# %%
data['age'].isnull().sum()

# %% [markdown]
# # 2.3 Dealing with Duplicates and Wrong Formats. Finding duplicate rows: duplicated()

# %%
data.duplicated()

# %%
data.duplicated().sum()

# %%
#removing duplicates
dup_remove = data.drop_duplicates()
dup_remove

# %%
#Wrong Formats

data.dtypes

# %%
# data['age'] = data['age'].astype(int)
data['age'] = data['age'].apply(int)
data

# %%
pd.unique(data['age'])

# %%
data.dtypes

# %%
# Alternative approach

data = data.astype({"age":'int'})
data

# %%
data.dtypes
