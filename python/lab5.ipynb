# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
import missingno as msno 
import warnings
warnings.filterwarnings('ignore')

# %%
#the applicants dataset shall be used 
data = pd.read_csv('Applicants.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
# data.head(20)
data.tail(20)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 594  LP002938    Male     Yes          0      Graduate           Yes
# 595  LP002940    Male      No          0  Not Graduate            No
# 596  LP002941    Male     Yes          2  Not Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 598  LP002945    Male     Yes          0      Graduate           Yes
# 599  LP002948    Male     Yes          2      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 601  LP002950    Male     Yes          0  Not Graduate           NaN
# 602  LP002953    Male     Yes         3+      Graduate            No
# 603  LP002958    Male      No          0      Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# ...

# %% [markdown]
# # finding missing values

# %%
# data.isna()   #notna()
# data.notna()
data.isna().sum()  #total no of missing
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.notna().sum()
# Out:
# Loan_ID              614
# Gender               601
# Married              611
# Dependents           599
# Education            614
# Self_Employed        582
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           592
# Loan_Amount_Term     600
# Credit_History       564
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %%
data['Gender'].isna().sum() #To count the missing values in particular column
# Out:
# 13

# %%
data['Loan_ID'].isna().sum()
# Out:
# 0

# %%
data['LoanAmount'].isna().sum()
# Out:
# 22

# %%
`#isnull() , notnull()

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Loan_ID              614
# Gender               601
# Married              611
# Dependents           599
# Education            614
# Self_Employed        582
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           592
# Loan_Amount_Term     600
# Credit_History       564
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %%
#uniques values: unique()

# %%
# pd.unique(data['Gender'])
# pd.unique(data['Education'])
# pd.unique(data['Dependents'])
# data['Gender'].value_counts()
data['LoanAmount'].value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %% [markdown]
# # visualization of missing values

# %%
#matrix plot 
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(data, figsize=(10,4), fontsize=12, color=(0.2,0.4,0.5))
# Out:
# <AxesSubplot:>

# %%
#Bar Chart
# msno.bar(data)
msno.bar(data,color='pink',sort='descending')
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
#dendogram
msno.dendrogram(data, orientation="top")
# Out:
# <AxesSubplot:>

# %%
#Dealing with missing value

# %%
#deleting , replacing, inpuatation(substitution), regressions technique

# %%
#dropna
df =pd.read_csv('students.csv')
df
# Out:
#    name   age  gender      genre
# 0     A  20.0       0     HipHop
# 1     B  23.0       0     HipHop
# 2     C  25.0       0        NaN
# 3     D  26.0       0       Jazz
# 4     E  29.0       0       Jazz
# 5     F  30.0       0       Jazz
# 6     G   NaN       0  Classical
# 7     H  33.0       0  Classical
# 8     I  37.0       0  Classical
# 9     J  20.0       1      Dance
# 10    K  21.0       1        NaN
# 11    L  25.0       1      Dance
# 12    M  26.0       1   Acoustic
# 13    N   NaN       1   Acoustic
# 14    O  30.0       1   Acoustic
# 15    P  31.0       1  Classical
# 16    Q  34.0       1  Classical
# 17    R   NaN       1  Classical
# 18    A  20.0       0     HipHop
# 19    H  33.0       0  Classical

# %%
df.isnull().sum()
# Out:
# name      0
# age       3
# gender    0
# genre     2
# dtype: int64

# %%
df['age'].isnull().sum()
# Out:
# 3

# %%
df2 = df.dropna(axis=0) #axis=1 for column
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9356/1856979142.py in <module>
# ----> 1 df2 = df.dropna(axis=0) #axis=1 for column
#       2 df2
#
# NameError: name 'df' is not defined

# %%
df.dropna(axis=1, inplace=True)
df
# Out:
#    name  gender
# 0     A       0
# 1     B       0
# 2     C       0
# 3     D       0
# 4     E       0
# 5     F       0
# 6     G       0
# 7     H       0
# 8     I       0
# 9     J       1
# 10    K       1
# 11    L       1
# 12    M       1
# 13    N       1
# 14    O       1
# 15    P       1
# 16    Q       1
# 17    R       1
# 18    A       0
# 19    H       0

# %%
df3=df.dropna(axis=0)
df3
# Out:
#    name   age  gender      genre
# 0     A  20.0       0     HipHop
# 1     B  23.0       0     HipHop
# 3     D  26.0       0       Jazz
# 4     E  29.0       0       Jazz
# 5     F  30.0       0       Jazz
# 7     H  33.0       0  Classical
# 8     I  37.0       0  Classical
# 9     J  20.0       1      Dance
# 11    L  25.0       1      Dance
# 12    M  26.0       1   Acoustic
# 14    O  30.0       1   Acoustic
# 15    P  31.0       1  Classical
# 16    Q  34.0       1  Classical
# 18    A  20.0       0     HipHop
# 19    H  33.0       0  Classical

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    15 non-null     object
#  1   age     15 non-null     float64
#  2   gender  15 non-null     int64
#  3   genre   15 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 600.0+ bytes

# %%
#Replacing method

# %%
mydf = df.fillna('unknown')
mydf
# Out:
#    name      age  gender      genre
# 0     A     20.0       0     HipHop
# 1     B     23.0       0     HipHop
# 2     C     25.0       0    unknown
# 3     D     26.0       0       Jazz
# 4     E     29.0       0       Jazz
# 5     F     30.0       0       Jazz
# 6     G  unknown       0  Classical
# 7     H     33.0       0  Classical
# 8     I     37.0       0  Classical
# 9     J     20.0       1      Dance
# 10    K     21.0       1    unknown
# 11    L     25.0       1      Dance
# 12    M     26.0       1   Acoustic
# 13    N  unknown       1   Acoustic
# 14    O     30.0       1   Acoustic
# 15    P     31.0       1  Classical
# 16    Q     34.0       1  Classical
# 17    R  unknown       1  Classical
# 18    A     20.0       0     HipHop
# 19    H     33.0       0  Classical

# %% [markdown]
# mydf.isnull().sum()

# %%
mydf.isnull().sum()
# Out:
# name      0
# age       0
# gender    0
# genre     0
# dtype: int64

# %%
#mydf = df['genre'].fillna('unkown') #specific columns

# %%
#Imputation method using mean median mode

# %%
df 
# imputeValue = df['age'].mean()
# imputeValue
# df['age'].fillna(imputeValue, inplace=True)
# df

imputeValue = df['age'].mode()
imputeValue
# Out:
# 0    20.0
# dtype: float64

# %%
#dealing with duplicates and wrong formats

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
#removing duplicates
df_noDup = df.drop_duplicates()
df_noDup
# Out:
#    name   age  gender      genre
# 0     A  20.0       0     HipHop
# 1     B  23.0       0     HipHop
# 2     C  25.0       0        NaN
# 3     D  26.0       0       Jazz
# 4     E  29.0       0       Jazz
# 5     F  30.0       0       Jazz
# 6     G   NaN       0  Classical
# 7     H  33.0       0  Classical
# 8     I  37.0       0  Classical
# 9     J  20.0       1      Dance
# 10    K  21.0       1        NaN
# 11    L  25.0       1      Dance
# 12    M  26.0       1   Acoustic
# 13    N   NaN       1   Acoustic
# 14    O  30.0       1   Acoustic
# 15    P  31.0       1  Classical
# 16    Q  34.0       1  Classical
# 17    R   NaN       1  Classical

# %% [markdown]
# # wrong formats

# %%
df.dtypes
# Out:
# name       object
# age       float64
# gender      int64
# genre      object
# dtype: object

# %%
df['age'] = df['age'].astype(int)
df
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12192/3324038291.py in <module>
# ----> 1 df['age'] = df['age'].astype(int)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
pd.unique(df['age'])
# Out:
# array([20., 23., 25., 26., 29., 30., nan, 33., 37., 21., 31., 34.])

# %%
# imputeValue = df['age'].mean()
# imputeValue
df['age'].fillna(imputeValue, inplace=True)
df
# Out:
#    name        age  gender      genre
# 0     A  20.000000       0     HipHop
# 1     B  23.000000       0     HipHop
# 2     C  25.000000       0        NaN
# 3     D  26.000000       0       Jazz
# 4     E  29.000000       0       Jazz
# 5     F  30.000000       0       Jazz
# 6     G  27.235294       0  Classical
# 7     H  33.000000       0  Classical
# 8     I  37.000000       0  Classical
# 9     J  20.000000       1      Dance
# 10    K  21.000000       1        NaN
# 11    L  25.000000       1      Dance
# 12    M  26.000000       1   Acoustic
# 13    N  27.235294       1   Acoustic
# 14    O  30.000000       1   Acoustic
# 15    P  31.000000       1  Classical
# 16    Q  34.000000       1  Classical
# 17    R  27.235294       1  Classical
# 18    A  20.000000       0     HipHop
# 19    H  33.000000       0  Classical

# %%
df.dtypes
# Out:
# name       object
# age       float64
# gender      int64
# genre      object
# dtype: object

# %%
# df['age'] = df['age'].astype(int)
df['age'] = df['age'].apply(int)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9356/4275085572.py in <module>
#       1 # df['age'] = df['age'].astype(int)
# ----> 2 df['age'] = df['age'].apply(int)
#       3 df
#
# NameError: name 'df' is not defined
