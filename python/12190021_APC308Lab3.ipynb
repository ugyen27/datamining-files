# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # applicant data Extraction

# %%
applicant = pd.read_csv('Applicants.csv')
applicant
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Export to Excel 
applicant.to_excel("applicant.xlsx", sheet_name="App Excel sheet")

# %%
#Deleting multiple coulumns from dataset
applicant.drop(['Married','Education'],axis=1,inplace=True)

# %%
applicant.head()   
applicant.head(9)
applicant.tail()
applicant.tail(5)
# Out:
#       Loan_ID  Gender Dependents Self_Employed  ApplicantIncome  \
# 609  LP002978  Female          0            No             2900
# 610  LP002979    Male         3+            No             4106
# 611  LP002983    Male          1            No             8072
# 612  LP002984    Male          2            No             7583
# 613  LP002990  Female          0           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area Loan_Status
# 609         Rural           Y
# 610         Rural           Y
# 611         Urban           Y
# 612         Urban           Y
# ...

# %%
# some useful attributes  
applicant.dtypes

applicant.index

applicant.columns

applicant.info() 

applicant.T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Dependents         599 non-null    object
#  3   Self_Employed      582 non-null    object
#  4   ApplicantIncome    614 non-null    int64
#  5   CoapplicantIncome  614 non-null    float64
#  6   LoanAmount         592 non-null    float64
#  7   Loan_Amount_Term   600 non-null    float64
#  8   Credit_History     564 non-null    float64
#  9   Property_Area      614 non-null    object
#  10  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 52.9+ KB
#                         0         1         2         3         4         5    \
# Loan_ID            LP001002  LP001003  LP001005  LP001006  LP001008  LP001011
# ...

# %%
# Filtering

#Filtering columns by name
applicant['ApplicantIncome']

applicant.ApplicantIncome

applicant[ ['ApplicantIncome', 'LoanAmount']]

applicant['Loan_Amount_Term'] * applicant['Credit_History']
# Out:
# 0      360.0
# 1      360.0
# 2      360.0
# 3      360.0
# 4      360.0
#        ...
# 609    360.0
# 610    180.0
# 611    360.0
# 612    360.0
# 613      0.0
# Length: 614, dtype: float64

# %%
#Filtering rows by slicing
# applicant[0:30:2]

applicant[600:400:-2]

applicant.loc[:]

#Filtering columns by label: loc

applicant.loc[:30:3, ["Loan_ID", "ApplicantIncome"]]

# #Filtering by values

applicant[
applicant['LoanAmount'] >= 500]


applicant[(
applicant['ApplicantIncome'] >500) & (
applicant['LoanAmount'] >300)]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 21   LP001046    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 67   LP001233    Male     Yes          1  Graduate            No
# 126  LP001448     NaN     Yes         3+  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 155  LP001536    Male     Yes         3+  Graduate            No
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 177  LP001610    Male     Yes         3+  Graduate            No
# 258  LP001859    Male     Yes          0  Graduate            No
# 260  LP001865    Male     Yes          1  Graduate            No
# 278  LP001907    Male     Yes          0  Graduate            No
# 308  LP001996    Male      No          0  Graduate            No
# ...

# %% [markdown]
# # Aggregation / Summary Stats

# %%
applicant.mean()

applicant.mean(0)


applicant["LoanAmount"].mean()


applicant["LoanAmount"].std()


applicant["LoanAmount"].min()


applicant["LoanAmount"].max()


applicant["LoanAmount"].median()

applicant["LoanAmount"].describe()


applicant["Loan_Amount_Term"].value_counts()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_11312/239523462.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   applicant.mean()
# C:\Users\HP\AppData\Local\Temp/ipykernel_11312/239523462.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   applicant.mean(0)
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
# Sorting and copying

applicant.sort_values(by="Loan_ID")


applicant.sort_values(by="LoanAmount")


applicant.sort_values(by="LoanAmount", ascending=False)

applicantClone = app_data.copy()
applicantClone
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Grouping

applicant.groupby("Education").count()

applicant.groupby("Dependents").count()

applicant.groupby("Education").mean()

applicant.groupby("Dependents").std()
# Out:
#             ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Dependents
# 0               5029.420772        2630.540915   75.848072         57.954215
# 1               5587.399149        1830.043127   95.097402         75.446993
# 2               3153.828577        2556.268525   71.283018         64.914970
# 3+             13603.938611        6050.789044  134.885329         79.571300
#
#             Credit_History
# Dependents
# 0                 0.350019
# 1                 0.364464
# 2                 0.356353
# 3+                0.424744

# %% [markdown]
# # Plotting into graph

# %%
applicant.plot(kind = 'scatter', x = 'LoanAmount', y = 'ApplicantIncome')

applicant.plot(kind = 'hist', x = 'LoanAmount', y = 'ApplicantIncome')
# Out:
# <AxesSubplot:ylabel='Frequency'>
