# %%
from numpy import array, arange
A = arange(1, 10, 0.5)
B = array([ [1, 2, 3], [ 7, 8, 9], [4, 5, 6] ], float)
# print (A.size + B.size)
# print (A.shape)  # how about B.shape ??
# print(B.shape)
# print (B.ndim)
# print (B * 4)
# print (B + len(A) )
# print (A[:5]) # Slicing operation
print (B[1:3, ::2])
# print(B.size)
# Out:
# [[7. 9.]
#  [4. 6.]]

# %%
import matplotlib.pyplot as p
x = [1, 2, 3, 4, 5, 6]
y = [1, 2, 3, 4, 5, 6]
p.plot(x,y) # plot x and y
p.xlabel('X axis')
p.ylabel('Y axis')
p.show() # show on screen

# %%
import matplotlib.pyplot as p
from numpy import *
x = arange(1,30,5)
y = arange(20,0,-4)
z = random.random(10) # 10 random Nos
p.plot(x,'ro', y, 'g^', z, 'bD')
p.title('demo of scatter plot')
p.show()

# %%
import matplotlib.pyplot as p
from numpy import *
x = arange(1,30,5)
y = arange(20,0,-4)
z = random.random(10) # 10 random Nos
p.plot(x,'ro', y, 'g^', z, 'bD')
p.title('demo of scatter plot')
p.show()

# %%
import matplotlib.pyplot as p
import numpy as np
x = np.arange(0.0, 10.0, 0.1)
p.plot(x, np.sin(2*x), 'g--', label='sine')
p.plot(x, np.cos(2*x), 'r-', label='cosine')
p.legend() # or p.legend((‘sine’, ‘cosine’))
p.xlabel('X values')
p.ylabel('Y values')
p.title('Plot of Trig Functions')
p.grid(True)
p.show()

# %%
import matplotlib.pyplot as p
import numpy as np
data = np.random.randn(1000) # generate 1000 random numbers
p.hist(data) # plot with the defaults
p.xlabel('Values')
p.ylabel('Distribution')
p.title('Simple Probability Distribution')
p.show()

# %%
import matplotlib.pyplot as p
p.figure(figsize = (8,8)) # looks best if the figure & axes are squares
p.axes([0.1, 0.1, 0.8, 0.8])
names = ('Guanine', 'Thymine', 'Cytosine', 'Adenine')
data = [20, 25, 40, 15]
exp = (0, 0, 0.06, 0)
p.pie(data, explode=exp, labels=names, autopct='%1.1f%%', shadow=True)
p.title('DNA Base Sequence')
p.show()

# %%
from matplotlib.pyplot import *
from numpy import *
x = arange(0.0, 5.0, 0.1)
y = arange(0.0, 2.0, 0.01)
subplot(211)
plot(x, cos(2*pi*x)*exp(-x), 'bo')
grid(True)
ylabel('Oscilation')
title('Demo of 2 subplots')
subplot(212)
plot(y, cos(2*pi*y), 'r--')
grid(True)
xlabel('time (s)')
ylabel('oscilation')
show()

# %%
import numpy as np
import matplotlib.pyplot as p
data = np.loadtxt('input.txt')
p.plot(data[:,0], data[:,1], 'mD')
p.xlabel('X values')
p.ylabel('Y values')
p.xlim(0.0, 10.) # set x limit
p.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_2156/3000435287.py:3: UserWarning: loadtxt: Empty input file: "input.txt"
#   data = np.loadtxt('input.txt')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2156/3000435287.py in <module>
#       2 import matplotlib.pyplot as p
#       3 data = np.loadtxt('input.txt')
# ----> 4 p.plot(data[:,0], data[:,1], 'mD')
#       5 p.xlabel('X values')
#       6 p.ylabel('Y values')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('classic')
# %matplotlib inline

# %%
# Create some data for plotting 

x = np.linspace(10, 20, 1000)
y = np.cumsum(np.random.randn(1000))

# %%
# plot the data using Matplotlib defaults

plt.plot(x, y)
plt.legend('A', loc='upper left');

# %%
# Now, let us do the same plotting using Seaborn
import seaborn as sns
sns.set(style="white")             
#sns.set(style="white")              # other styles: whitegrid, darkgrid, dark, etc

plt.plot(x, y)
plt.legend('A', loc='upper left');

# %%
sns.get_dataset_names() 

iris = sns.load_dataset("iris")

iris

type(iris)

# %%
iris

# %%
# iris.describe()
# iris.info()
iris.tail()

# %%
iris.head()

# %%
iris.dtypes

# %%
iris.min()

# %%
iris['sepal_length']

# %%
iris['sepal_length'] * iris ['petal_length']

# %%
# simple plot using lineplot() 
import warnings                          # to silence warning if need be
warnings.filterwarnings('ignore')

x = [i for i in range(20)]
y = [j*2 for j in range(20)]

sns.lineplot(x,y)

# %%
# Setting xlabel and ylabel
p = sns.lineplot(x,y)

p.set( xlabel = "X-Axis", ylabel = "Y-Axis")

# %%
# plotting from a dataset 

tipData = sns.load_dataset("tips")

tipData

# %%
sns.lineplot(data=tipData, x="tip", y="total_bill")

# %%
sns.lineplot(data=tipData, x="tip", y="total_bill", hue="time")           # meaning?

# %%
iris

# %%
datairis = sns.load_dataset("iris")

datairis

# %%
sns.lineplot(data=datairis, x="sepal_width", y="petal_width", hue="species")

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(data=tipData, x="total_bill", y="tip")

# %%
sns.scatterplot(data=tipData, x="total_bill", y="tip", hue="day")       # try a different hue

# %%
tipData

# %%
sns.scatterplot(data=datairis, x="sepal_width", y="petal_width", hue="species")

# %%
sns.displot(data=tipData, x="tip", col="sex")             # try different x and col

# %%
tipData

# %%
sns.histplot(data=tipData, x="total_bill")             # try different x and col

# %%
# sns.pairplot(iris)

sns.pairplot(iris, hue="species")

# %%
sns.pairplot(tipData)

# %%
sns.pairplot(tipData, hue="sex")

# %%
tipData

# %%
sns.boxplot( iris['sepal_width'] )                                # meaning?

# %%
sns.boxplot( x=iris['species'], y=iris['sepal_width'] )            # meaning?

# %%
sns.boxplot( tipData['tip'] )

# %%
sns.boxplot( x=tipData['smoker'], y=tipData['total_bill'] )

# %%
sns.boxplot( x=tipData['sex'], y=tipData['total_bill'] )

# %%
# basic demo of heatmap

data = [ [1, 2, 3], [1, 5, 3], [1, 8, 3]] 

sns.heatmap(data)

# %%
# plot heatmap from an example dataset named "flights"

flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")

sns.heatmap(flights)
